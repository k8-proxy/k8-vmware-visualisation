# %% [markdown]
# # VMWare Visualisation

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from IPython.core.display import HTML

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
json_file = 'data/machines.json' 
df = pd.read_json(json_file)

csv_file = 'data/all_machines.csv'
df = pd.read_csv(csv_file)
df
# Out:
#           CreateDate                                   Name  \
# 0   24/11/2020 11:46                             Controller
# 1   25/11/2020 09:43                                k8s-Sow
# 2   08/12/2020 09:50                                ICAP_01
# 3   11/12/2020 11:35                      haproxy-icap-wiki
# 4   11/12/2020 11:36                       haproxy-web-wiki
# 5   11/12/2020 14:26                           import-proxy
# 6   01/01/1970 00:00                           minio-server
# 7   16/12/2020 14:00                           file-gateway
# 8   16/12/2020 19:10                          proxy-rebuild
# 9   17/12/2020 08:21                                 GOV-UK
# 10  01/01/1970 00:00                                desktop
# 11  17/12/2020 15:51  Packer-export-i-0259c38b36cbaabc2.ova
# 12  17/12/2020 16:36  Packer-export-i-07cb42cec69a8d5fa.ova
# 13  17/12/2020 17:36  Packer-export-i-04364bb983092f191.ova
# 14  21/12/2020 09:52          icap-perf-load-generator-v0.6
# 15  22/12/2020 13:04                       proxy-rebuild-01
# 16  05/01/2021 17:20                         filedrop-test0
# 17  01/01/1970 00:00                              logtrixia
# 18  01/01/1970 00:00                               filedrop
# 19  07/01/2021 09:42                          test-delete-1
# 20  07/01/2021 09:42                          test-delete-2
# 21  07/01/2021 09:42                          test-delete-3
# 22  07/01/2021 09:42                          test-delete-4
# 23  07/01/2021 11:42                               OPNsense
# 24  07/01/2021 12:46                         centos-testing
# 25  07/01/2021 17:25                       TestInstallation
# 26  27/11/2020 15:15     icap-performance-traffic-generator
#
#                                      Guest            GuestId  NumCpu  \
# 0         Controller:Ubuntu Linux (64-bit)      ubuntu64Guest       1
# 1                                 k8s-Sow:      ubuntu64Guest       8
# 2                                 ICAP_01:      ubuntu64Guest       8
# 3                       haproxy-icap-wiki:      ubuntu64Guest       1
# 4                        haproxy-web-wiki:      ubuntu64Guest       1
# 5                            import-proxy:      ubuntu64Guest       2
# 6                            minio-server:      ubuntu64Guest       2
# 7                            file-gateway:       otherGuest64       2
# 8                           proxy-rebuild:      ubuntu64Guest       2
# 9                                  GOV-UK:      ubuntu64Guest       2
# 10                                desktop:      ubuntu64Guest       2
# 11  Packer-export-i-0259c38b36cbaabc2.ova:      ubuntu64Guest       1
# 12  Packer-export-i-07cb42cec69a8d5fa.ova:      ubuntu64Guest       1
# 13  Packer-export-i-04364bb983092f191.ova:      ubuntu64Guest       1
# 14          icap-perf-load-generator-v0.6:      ubuntu64Guest      12
# 15                       proxy-rebuild-01:      ubuntu64Guest       2
# 16                         filedrop-test0:      ubuntu64Guest       2
# 17         logtrixia:Ubuntu Linux (64-bit)      ubuntu64Guest       2
# 18                               filedrop:      ubuntu64Guest       2
# 19                          test-delete-1:      ubuntu64Guest       1
# 20     test-delete-2:Ubuntu Linux (64-bit)      ubuntu64Guest       1
# 21     test-delete-3:Ubuntu Linux (64-bit)      ubuntu64Guest       1
# 22     test-delete-4:Ubuntu Linux (64-bit)      ubuntu64Guest       1
# 23                               OPNsense:  freebsd12_64Guest       2
# 24        centos-testing:CentOS 8 (64-bit)    centos8_64Guest       1
# 25      TestInstallation:CentOS 8 (64-bit)    centos8_64Guest       1
# 26     icap-performance-traffic-generator:      ubuntu64Guest       2
#
#     MemoryMB  PowerState Version            VMHostId  \
# 0       1024   PoweredOn     v14  HostSystem-ha-host
# 1       6144  PoweredOff     v14  HostSystem-ha-host
# 2       6144  PoweredOff     v14  HostSystem-ha-host
# 3       1024  PoweredOff     v14  HostSystem-ha-host
# 4       1024  PoweredOff     v14  HostSystem-ha-host
# 5       8192  PoweredOff     v14  HostSystem-ha-host
# 6       2048  PoweredOff     v13  HostSystem-ha-host
# 7       4096  PoweredOff     v10  HostSystem-ha-host
# 8       8192  PoweredOff     v14  HostSystem-ha-host
# 9       2048  PoweredOff     v14  HostSystem-ha-host
# 10      4096  PoweredOff     v13  HostSystem-ha-host
# 11      2048  PoweredOff      v7  HostSystem-ha-host
# 12      2048  PoweredOff      v7  HostSystem-ha-host
# 13      2048  PoweredOff      v7  HostSystem-ha-host
# 14      8192  PoweredOff     v10  HostSystem-ha-host
# 15      8192  PoweredOff     v14  HostSystem-ha-host
# 16      2048  PoweredOff     v13  HostSystem-ha-host
# 17      8192   PoweredOn     v13  HostSystem-ha-host
# 18      2048  PoweredOff     v13  HostSystem-ha-host
# 19      1024  PoweredOff     v14  HostSystem-ha-host
# 20      1024   PoweredOn     v14  HostSystem-ha-host
# 21      1024   PoweredOn     v14  HostSystem-ha-host
# 22      1024   PoweredOn     v14  HostSystem-ha-host
# 23      2048   PoweredOn     v14  HostSystem-ha-host
# 24      2048   PoweredOn     v14  HostSystem-ha-host
# 25      2048   PoweredOn     v14  HostSystem-ha-host
# 26      4096  PoweredOff      v7  HostSystem-ha-host
#
#                        VMHost  VMPathName  \
# 0   esxi01.glasswall-icap.com         NaN
# 1   esxi01.glasswall-icap.com         NaN
# 2   esxi01.glasswall-icap.com         NaN
# 3   esxi01.glasswall-icap.com         NaN
# 4   esxi01.glasswall-icap.com         NaN
# 5   esxi01.glasswall-icap.com         NaN
# 6   esxi01.glasswall-icap.com         NaN
# 7   esxi01.glasswall-icap.com         NaN
# 8   esxi01.glasswall-icap.com         NaN
# 9   esxi01.glasswall-icap.com         NaN
# 10  esxi01.glasswall-icap.com         NaN
# 11  esxi01.glasswall-icap.com         NaN
# 12  esxi01.glasswall-icap.com         NaN
# 13  esxi01.glasswall-icap.com         NaN
# 14  esxi01.glasswall-icap.com         NaN
# 15  esxi01.glasswall-icap.com         NaN
# 16  esxi01.glasswall-icap.com         NaN
# 17  esxi01.glasswall-icap.com         NaN
# 18  esxi01.glasswall-icap.com         NaN
# 19  esxi01.glasswall-icap.com         NaN
# 20  esxi01.glasswall-icap.com         NaN
# 21  esxi01.glasswall-icap.com         NaN
# 22  esxi01.glasswall-icap.com         NaN
# 23  esxi01.glasswall-icap.com         NaN
# 24  esxi01.glasswall-icap.com         NaN
# 25  esxi01.glasswall-icap.com         NaN
# 26  esxi01.glasswall-icap.com         NaN
#
#                                                 Notes  \
# 0                                         dont_delete
# 1   dont_delete\nClone this VM if you would like t...
# 2   dont_delete\nClone this VM if you would like t...
# 3                                         dont_delete
# 4                                         dont_delete
# 5                                         dont_delete
# 6                                         dont_delete
# 7                          dont_delete\nAWS-Appliance
# 8                     dont_delete\ncreated by: Pranay
# 9                                         dont_delete
# 10                                        dont_delete
# 11                                        dont_delete
# 12                                        dont_delete
# 13                                        dont_delete
# 14                                        dont_delete
# 15                    dont_delete\ncreated by: Pranay
# 16                                        dont_delete
# 17                                        dont_delete
# 18                                        dont_delete
# 19                                          delete_me
# 20                                        dont_delete
# 21                                        dont_delete
# 22                                        dont_delete
# 23                                        dont_delete
# 24                                                NaN
# 25                                                NaN
# 26                                        dont_delete
#
#                             PersistentId HardwareVersion  UsedSpaceGB  \
# 0   520c8b1c-4c08-9c7c-8c07-16f9d98562a3          vmx-14    65.080298
# 1   524ef5d5-fbf1-bf2c-30a9-dae45a903abd          vmx-14     2.474617
# 2   52d22cd9-d426-4610-9824-95ca12647d38          vmx-14    17.732291
# 3   524d2bf0-3ac0-796f-23b3-f3bfd5cb03c6          vmx-14    12.300789
# 4   527dc235-3fda-2d7a-6414-80322ab2e6fa          vmx-14    12.381844
# 5   521c4205-c950-c229-29cd-ff6b89cafcf9          vmx-14    14.320321
# 6                                    NaN          vmx-13    48.828136
# 7   52e74898-905f-0eff-2214-1743724008fb          vmx-10   100.000008
# 8   52cea534-f65c-1a19-a36e-37c56de42775          vmx-14    12.691414
# 9   52eeaec4-a096-ba3e-0915-2d6c499cf38c          vmx-14    20.288318
# 10                                   NaN          vmx-13     9.765636
# 11  52bf4027-16d6-bb65-36c5-9cded1ac2a77          vmx-07     8.000008
# 12  52d7b5b7-495b-20c1-692e-10f81bf38103          vmx-07     8.000000
# 13  52611fd7-6a9e-c013-ba8a-a0e721b91410          vmx-07     8.000000
# 14  529240fd-41e4-1fa9-a601-9647ca9258a6          vmx-10    41.052518
# 15  5293b6f4-f2fc-bf6c-a5eb-7d5c9fe52f80          vmx-14    12.691414
# 16  52c7c7fb-3d07-975f-f404-06eb20c24cee          vmx-13     7.219735
# 17                                   NaN          vmx-13    56.908214
# 18                                   NaN          vmx-13     9.765636
# 19  52a1b4aa-9e7c-abfb-24a1-672080fbc66a          vmx-14     0.000008
# 20  52a1b4aa-9e7c-abfb-24a1-672080fbc66a          vmx-14     3.737313
# 21  52a1b4aa-9e7c-abfb-24a1-672080fbc66a          vmx-14     3.737313
# 22  52a1b4aa-9e7c-abfb-24a1-672080fbc66a          vmx-14     3.737313
# 23  521d330d-04c0-11d5-be0e-7818cfbb2407          vmx-14    22.080086
# 24  522fb36e-4a08-5a8f-7812-1b0d1ceb535b          vmx-14    18.078377
# 25  52de03ee-c829-7e4f-36e8-f5ec021d408a          vmx-14     2.078377
# 26  5243acd1-431e-faa3-a00a-a6c03ee8fa1f          vmx-07     7.551305
#
#     ProvisionedSpaceGB                        VMResourceConfiguration  \
# 0           129.079322   CpuShares:Normal/1000 MemShares:Normal/10240
# 1            38.251752   CpuShares:Normal/8000 MemShares:Normal/61440
# 2            38.252590   CpuShares:Normal/8000 MemShares:Normal/61440
# 3            17.238000   CpuShares:Normal/1000 MemShares:Normal/10240
# 4            17.238000   CpuShares:Normal/1000 MemShares:Normal/10240
# 5            24.239964   CpuShares:Normal/2000 MemShares:Normal/81920
# 6            51.019810   CpuShares:Normal/2000 MemShares:Normal/20480
# 7           104.191640   CpuShares:Normal/2000 MemShares:Normal/40960
# 8            24.239964   CpuShares:Normal/2000 MemShares:Normal/81920
# 9            32.240188   CpuShares:Normal/2000 MemShares:Normal/20480
# 10           13.957310   CpuShares:Normal/2000 MemShares:Normal/40960
# 11           10.189675   CpuShares:Normal/1000 MemShares:Normal/20480
# 12           10.688576   CpuShares:Normal/1000 MemShares:Normal/20480
# 13           10.688576   CpuShares:Normal/1000 MemShares:Normal/20480
# 14          110.255942  CpuShares:Normal/12000 MemShares:Normal/81920
# 15           24.239964   CpuShares:Normal/2000 MemShares:Normal/81920
# 16           11.957307   CpuShares:Normal/2000 MemShares:Normal/20480
# 17           56.908214   CpuShares:Normal/2000 MemShares:Normal/81920
# 18           11.945190   CpuShares:Normal/2000 MemShares:Normal/20480
# 19           17.238000   CpuShares:Normal/1000 MemShares:Normal/10240
# 20           17.078134   CpuShares:Normal/1000 MemShares:Normal/10240
# 21           17.078134   CpuShares:Normal/1000 MemShares:Normal/10240
# 22           17.078134   CpuShares:Normal/1000 MemShares:Normal/10240
# 23           22.080087   CpuShares:Normal/2000 MemShares:Normal/20480
# 24           18.078378   CpuShares:Normal/1000 MemShares:Normal/20480
# 25           18.078378   CpuShares:Normal/1000 MemShares:Normal/20480
# 26           54.193132   CpuShares:Normal/2000 MemShares:Normal/40960
#
#                     Id                                                Uid
# 0     VirtualMachine-1  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 1    VirtualMachine-10  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 2   VirtualMachine-303  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 3   VirtualMachine-310  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 4   VirtualMachine-311  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 5   VirtualMachine-316  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 6   VirtualMachine-382  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 7   VirtualMachine-386  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 8   VirtualMachine-397  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 9   VirtualMachine-409  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 10  VirtualMachine-416  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 11  VirtualMachine-417  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 12  VirtualMachine-418  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 13  VirtualMachine-421  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 14  VirtualMachine-431  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 15  VirtualMachine-437  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 16  VirtualMachine-445  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 17  VirtualMachine-454  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 18  VirtualMachine-457  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 19  VirtualMachine-462  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 20  VirtualMachine-464  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 21  VirtualMachine-465  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 22  VirtualMachine-466  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 23  VirtualMachine-471  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 24  VirtualMachine-472  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 25  VirtualMachine-492  /VIServer=root@esxi01.glasswall-icap.com:443/V...
# 26   VirtualMachine-55  /VIServer=root@esxi01.glasswall-icap.com:443/V...

# %% [markdown]
# ## Power State

# %%
df.PowerState.value_counts()
# Out:
# PoweredOff    19
# PoweredOn      8
# Name: PowerState, dtype: int64

# %%
df.PowerState.value_counts().plot(kind='bar', figsize=(7, 6), rot=0) #kind='barh'
plt.xlabel("Power State", labelpad=14)
plt.ylabel("Counts", labelpad=14)
plt.title("Power State", y=1.02);

# %%
df.PowerState.value_counts().plot(kind='pie', figsize=(7, 6), rot=0) 
plt.title("Power State", y=1.02);

# %% [markdown]
# ## Number of CPUs

# %%
df.NumCpu.value_counts()
# Out:
# 2     12
# 1     12
# 8      2
# 12     1
# Name: NumCpu, dtype: int64

# %%
df.NumCpu.value_counts().plot(kind='bar', figsize=(7, 6), rot=0) #kind='barh'
plt.xlabel("Number of CPUs", labelpad=14)
plt.ylabel("Counts", labelpad=14)
plt.title("Number of CPUs", y=1.02);

# %%
df.NumCpu.value_counts().plot(kind='pie', figsize=(7, 6), rot=0) 
plt.title("Number of CPUs", y=1.02);

# %% [markdown]
# ## Memory

# %%
df.MemoryMB.value_counts()
# Out:
# 2048    10
# 1024     7
# 8192     5
# 4096     3
# 6144     2
# Name: MemoryMB, dtype: int64

# %%
df.MemoryMB.value_counts().plot(kind='bar', figsize=(7, 6), rot=0) #kind='barh'
plt.xlabel("Memory (MB)", labelpad=14)
plt.ylabel("Counts", labelpad=14)
plt.title("Memory (MB)", y=1.02);

# %%
df.MemoryMB.value_counts().plot(kind='pie', figsize=(7, 6), rot=0) 
plt.title("Memory (MB)", y=1.02);

# %% [markdown]
# ## Provisioned Space

# %%
xint = [x for x in range(len(df))]
y = np.asarray(df.ProvisionedSpaceGB)
plt.figure(figsize=(10, 6))
plt.plot(y, 'o-', color='black')
plt.xticks(xint)
plt.xlabel("VM", labelpad=14)
plt.ylabel("Provisioned Space (GB)", labelpad=14)
plt.title("Provisioned Space (GB)", y=1.02);

# %% [markdown]
# ## Used Space

# %%
y = np.asarray(df.UsedSpaceGB)
plt.figure(figsize=(10, 6))
plt.plot(y, 'o-', color='black')
plt.xticks(xint)
plt.xlabel("VM", labelpad=14)
plt.ylabel("Used Space (GB)", labelpad=14)
plt.title("Used Space (GB)", y=1.02);
