# %% [markdown]
# # K8-vmware Project Tracking

# %%
# %%capture
import sys
# !{sys.executable} -m pip install google-auth-oauthlib
# !{sys.executable} -m pip install google-api-python-client
# !{sys.executable} -m pip install xhtml2pdf
# !{sys.executable} -m pip install pdfrw

# %%
from modules.presentations import *
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# In this notebook we pull data from this google sheet
#
# https://docs.google.com/spreadsheets/d/13L9OodSo4Gp1vKPKpqEsi8vuoaxefuqhR6adXEvux5o/edit#gid=0
#
# See more related info here:
#
# https://docs.google.com/spreadsheets/d/1SetbtWlZC9fEddTbOzlnM36OQYBdtg0bbG4quq9ODKY/edit#gid=1064322020

# %%
sheet_name='Sheet1'
df = pull_data_from_gsh(sheet_name)
df
# Out:
#                    Name                                    Role In Project  \
# 0          Alekh Aneja                                    Python Developer
# 1        Ashish Belwase                                   Python Developer
# 2           Chris Diao                                    Delivery Manager
# 3          Faisal Adnan                                                TBD
# 4     Georgina González                                   Delivery Manager
# 5    Lwasampijja Baker                                      Data Scientist
# 6   M. Lucía Pappaterra  Visualize the information that is pulled from ...
# 7       Mahmoud Shaban   create a script to delete unnecessary VM machi...
# 8       Mariusz Ferdyn   Cloud Engineering, Devops, Health Check Creato...
# 9      Michael Hidalgo                 Security, Security event collection
# 10        Mohit Sengar                                           Developer
# 11           Nader Ali                                           Developer
# 12             Samarth                                           Developer
# 13       Shereen Farag   QA Testing & Documentation\naudit AWS and ESXI...
# 14              Son Ha                                           Developer
#
#                      Hours spent on project this week Total Hours Available  \
# 0                                                   5                     5
# 1                                             10 -15                     20
# 2                                                  30                    30
# 3                                                  20                    40
# 4                                                  40                    40
# 5                                                  30                    30
# 6                                                  24                    40
# 7                                                  10                 20-25
# 8                                                  30                 40-50
# 9                                                  40                    40
# 10  20 but requires more - there are tickets assig...                    40
# 11                                                 20                    40
# 12                                                 20                    20
# 13                                                 15                    40
# 14                                                 15                    25
#
#                                                Skills  \
# 0               Python, Docker, K8, Node.js, Java etc
# 1   Python, NodeJS, Unit Testing, Automation, Web ...
# 2   Project Management, Solutions Architect, Produ...
# 3      Python, Git, Github Action, DevOps, Monitoring
# 4   Project management, organization activities, d...
# 5                                 Python, Pandas, AWS
# 6   Data Science, Data Analysis and Visualisation,...
# 7   Scripting (Python, Bash), Linux, APIs, Swagger...
# 8   Cloud Azure, AWS, GCP, Integration Project, Ad...
# 9   Cyber Security, Application Security, Python P...
# 10  Node.JS, Azure,  ReactJs, AWS, Lambda Function...
# 11  Linux administration (intermediate) Python(beg...
# 12                                        Python, AWS
# 13              testing, documentation, python, Linux
# 14  Python, AWS, Lambda - S3- EC2, Linux Shell/ Ba...
#
#                            Tasks Currently Working On Blockers  \
# 0                            No task assigned for now
# 1   Tasks are finished but currently working on is...
# 2    To Visualise the VMWare (esxi01) and GW releases
# 3      Organizing tasks and visualizing test coverage
# 4   Managing the release from this week from the K...
# 5                             Visualising VMWARE data
# 6   Creating more VMware EXSi visualisations with ...
# 7   A bash script to test the rebuild API using cu...
# 8   OVA - kernel is not supported - testing which ...
# 9
# 10  https://github.com/k8-proxy/k8-rebuild-rest-ap...
# 11  https://github.com/k8-proxy/k8-vmware/issues/1...
# 12                              Improving test cases
# 13  #test-installation-documentation wherein we ar...
# 14  Creating AWS Lambda function that executes hea...
#
#                            Deliverables for this Week
# 0       https://github.com/k8-proxy/k8-vmware/pull/17
# 1   Created script to auto start/shutdown with con...
# 2   - Establish a Lambda code to extract informati...
# 3                                                 TBD
# 4   No PRs from my side. But this is the release w...
# 5   https://github.com/k8-proxy/k8-vmware-visualis...
# 6   PR: https://github.com/k8-proxy/k8-vmware-visu...
# 7   I am not done with the script yet. When I am f...
# 8   https://github.com/k8-proxy/vmware-scripts/pul...
# 9    https://github.com/k8-proxy/k8-vmware/issues/15
# 10  https://github.com/k8-proxy/k8-rebuild-rest-ap...
# 11  https://github.com/k8-proxy/vmware-scripts/tre...
# 12  https://github.com/k8-proxy/k8-vmware/issues/9...
# 13  Filling out this sheet as well as opening up i...
# 14  No deliverable yet - PR and video to be ready ...

# %%
create_presentation(df, 
                    file_name='K8-vmware Project Tracking '+sheet_name, 
                    table_title='K8-vmware Project Tracking',
                    columns_widths=[50, 65, 90, 60, 100, 120, 80, 120])

# %% [markdown]
# The presentation is in this folder: https://drive.google.com/drive/u/1/folders/1dELfGV6IMMII97tTjqSXeJwPAMEjtbDX
