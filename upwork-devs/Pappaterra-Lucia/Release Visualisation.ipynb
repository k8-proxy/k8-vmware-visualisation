# %% [markdown]
# # Release Visualisation

# %%
import requests
import pandas as pd
import re
import json
from IPython.core.display import HTML
from modules.Network import *
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
# Out:
# <style>.container { width:70% !important; }</style>

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# We get the json file with the information from
# https://wmwaredata.s3.us-east-2.amazonaws.com/releases.json

# %%
url = 'https://wmwaredata.s3.us-east-2.amazonaws.com/releases.json'
r = requests.get(url, allow_redirects=True)
open('data/releases.json', 'wb').write(r.content)
# Out:
# 13407

# %%
df = pd.read_json('data/releases.json')

descriptions = []
for i in range(len(df)):
    content = re.sub('<.*?>', '', df['release_name'].iloc[i])
    des = wrap_by_word(content, n=5)
    des = wrap_by_char(des, n=45)
    descriptions.append(des)
    
df['description'] = descriptions
df = df.drop('release_name', axis=1)
df = df.rename(columns={'repo_repo': 'repo_name'})
df = df[['repo_name', 'repo_url', 'release_tag', 'release_date', 'description']]
df
# Out:
#                  repo_name                                           repo_url  \
# 0   aws-jmeter-test-engine  https://github.com/k8-proxy/aws-jmeter-test-en...
# 1   aws-jmeter-test-engine  https://github.com/k8-proxy/aws-jmeter-test-en...
# 2   aws-jmeter-test-engine  https://github.com/k8-proxy/aws-jmeter-test-en...
# 3        glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 4        glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 5        glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 6        glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 7        glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 8        glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 9        glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 10       glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 11       glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 12       glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 13       glasswall-desktop      https://github.com/k8-proxy/glasswall-desktop
# 14        gp-load-balancer       https://github.com/k8-proxy/gp-load-balancer
# 15           gp-sharepoint          https://github.com/k8-proxy/gp-sharepoint
# 16           gp-sharepoint          https://github.com/k8-proxy/gp-sharepoint
# 17           gp-sharepoint          https://github.com/k8-proxy/gp-sharepoint
# 18           gp-sharepoint          https://github.com/k8-proxy/gp-sharepoint
# 19           gp-sharepoint          https://github.com/k8-proxy/gp-sharepoint
# 20           gp-sharepoint          https://github.com/k8-proxy/gp-sharepoint
# 21           gp-sharepoint          https://github.com/k8-proxy/gp-sharepoint
# 22           gp-sharepoint          https://github.com/k8-proxy/gp-sharepoint
# 23           gp-sharepoint          https://github.com/k8-proxy/gp-sharepoint
# 24   gp-sharepoint-plugins  https://github.com/k8-proxy/gp-sharepoint-plugins
# 25   gp-sharepoint-plugins  https://github.com/k8-proxy/gp-sharepoint-plugins
# 26   gp-sharepoint-plugins  https://github.com/k8-proxy/gp-sharepoint-plugins
# 27   gp-sharepoint-plugins  https://github.com/k8-proxy/gp-sharepoint-plugins
# 28   gp-sharepoint-plugins  https://github.com/k8-proxy/gp-sharepoint-plugins
# 29   gp-sharepoint-plugins  https://github.com/k8-proxy/gp-sharepoint-plugins
# 30   gp-sharepoint-plugins  https://github.com/k8-proxy/gp-sharepoint-plugins
# 31   gp-sharepoint-plugins  https://github.com/k8-proxy/gp-sharepoint-plugins
# 32   gp-sharepoint-plugins  https://github.com/k8-proxy/gp-sharepoint-plugins
#
#    release_tag          release_date  \
# 0       v0.2.1  2021-01-29T12:29:04Z
# 1       v0.2.0  2021-01-22T14:06:01Z
# 2       v0.1.0  2020-10-20T13:01:48Z
# 3       v1.0.0  2020-12-18T17:53:54Z
# 4       v0.9.0  2020-11-27T12:31:01Z
# 5       v0.1.7  2020-11-21T13:39:04Z
# 6       v0.1.6  2020-11-13T20:20:58Z
# 7       v0.1.5  2020-11-06T16:48:45Z
# 8       v0.1.4  2020-10-29T16:09:16Z
# 9       v0.1.3  2020-10-21T13:13:12Z
# 10      v0.1.2  2020-10-20T23:38:02Z
# 11      v0.1.1                  None
# 12      v0.1.1                  None
# 13      v0.1.0  2020-10-19T07:29:09Z
# 14      v0.1.0  2021-01-19T09:07:32Z
# 15     v0.0.10  2021-02-08T12:57:47Z
# 16      v0.0.9  2021-02-08T12:52:06Z
# 17      v0.0.8  2021-02-08T12:46:38Z
# 18      v0.0.7  2021-02-08T10:47:46Z
# 19      v0.0.6  2021-02-08T10:39:12Z
# 20      v0.0.5  2021-02-08T10:32:16Z
# 21      v0.0.4  2021-02-08T10:24:28Z
# 22      v0.0.3  2021-02-08T10:10:36Z
# 23      v0.0.2  2021-02-08T09:56:27Z
# 24     v0.0.10  2021-02-08T12:57:47Z
# 25      v0.0.9  2021-02-08T12:52:06Z
# 26      v0.0.8  2021-02-08T12:46:38Z
# 27      v0.0.7  2021-02-08T10:47:46Z
# 28      v0.0.6  2021-02-08T10:39:12Z
# 29      v0.0.5  2021-02-08T10:32:16Z
# 30      v0.0.4  2021-02-08T10:24:28Z
# 31      v0.0.3  2021-02-08T10:10:36Z
# 32      v0.0.2  2021-02-08T09:56:27Z
#
#                                           description
# 0   - Instructions simplified - Bugs\nfixed - New ...
# 1   * UI Updates - interface\nsupports trigger loa...
# 2   - Configured AWS Cloud Formation\nstack to aut...
# 3   Release Notes for v1.0.0 Policy\nManagement ap...
# 4   Release Notes for v0.9.0 Added\nThreat Intelli...
# 5   Release Notes for v0.1.7 Policy\nControl & Man...
# 6   Release Notes for v0.1.6 Added\nsupport for Pa...
# 7   Release Notes for v0.1.5 Local\nrebuild health...
# 8   Release Notes for v0.1.4 Processing\nrebuild l...
# 9   1. Fixed Video link 2.\nFixed Help Shortcut 4....
# 10  1. FIxed website link 2.\nFixed Linux broken link
# 11                                         Bug fixing
# 12                                        Bugs fixing
# 13      First release - online version\nof GW desktop
# 14  First tag with stable version\nof gp-load-bala...
# 15                                            v0.0.10
# 16                                             v0.0.9
# 17                                             v0.0.8
# 18                                             v0.0.7
# 19                                             v0.0.6
# 20                                             v0.0.5
# 21                                             v0.0.4
# 22                                             v0.0.3
# 23                                             v0.0.2
# 24                                            v0.0.10
# 25                                             v0.0.9
# 26                                             v0.0.8
# 27                                             v0.0.7
# 28                                             v0.0.6
# 29                                             v0.0.5
# 30                                             v0.0.4
# 31                                             v0.0.3
# 32                                             v0.0.2

# %% [markdown]
# ## Repo's Releases

# %%
# CREATE JSON FILE WITH NODES AND EDGES

network = Network()
network.groups = ['Repo', 'Tag', 'Date', 'Description']
network.groupSettings = group_settings_R

for repo in set(list(df['repo_name'])):
    
    # REPO
    network.add_node(label=repo, group='Repo')
    df1 = df[df['repo_name'] == repo].reset_index()
    
    for i in range(len(df1)):
        # TAG
        tag = 'Tag: ' + df1['release_tag'].iloc[i] 
        network.add_node(label=tag, group='Tag', repeat_nodes=True)
        network.add_edge(network.nodesIds[repo][0], network.nodesIds[tag][-1])
        df2 = df1[df1['release_tag'] == tag].reset_index()
        
        # DATE
        d = df1['release_date'].iloc[i]
        
        if d is not None:
            d = d.split('T')
            date = 'Date: '+ d[0] + '\nTime: ' + d[1][:-1]
        else:
            date = ''
        
        network.add_node(label=date, group='Date', repeat_nodes=True)
        network.add_edge(network.nodesIds[tag][-1], network.nodesIds[date][-1])
        
        # DESCRIPTION
        des = df1['description'].iloc[i]
        if des != '':
            network.add_node(label=des, group='Description', repeat_nodes=True)
            network.add_edge(network.nodesIds[date][-1], network.nodesIds[des][-1])
    
network.save_to_json('data/releases_nodes_edges.json')

# %%
# %%html
# <div id="mynetwork"></div>
# Out:
# <div id="mynetwork"></div>

# %%
# %%javascript
# requirejs.config({
#     paths: {
#         vis: 'vis'
#     }
# });
#
#
# require(['vis'], function(vis){
#
#     var json = $.getJSON("data/releases_nodes_edges.json")
#       .done(function(data){
#         var data = {
#           nodes: data.nodes,
#           edges: data.edges
#         };
#         var network = new vis.Network(container, data, options);
#       });
#
#     var options = {
#       width: '1000px',
#       height: '800px',
#       locale: 'en',
#       physics: true,
#       interaction: {
#         hover:true,
#         tooltipDelay: 300
#       },
#       layout: {
#         randomSeed: 1,
#         improvedLayout: true,
#       }
#     };
#
#     var container = document.getElementById("mynetwork");
# });
